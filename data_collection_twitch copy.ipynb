# %%
import requests
import json
import pymysql
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("mysql+pymysql://HIDDEN")

# %%
# This is getting the general access token


# Set the client ID and client secret for your Twitch application
client_id = 'HIDDEN'
client_secret = 'HIDDEN'

# Set the URL for the Twitch API endpoint to request an OAuth access token
url = 'https://id.twitch.tv/oauth2/token'
data = {'client_id': client_id, 'client_secret': client_secret, 'grant_type': 'client_credentials'}
response = requests.post(url, data=data)

# Check if the response status code is 200 (OK)
if response.status_code == 200:
    # If the response is successful, retrieve the access token from the JSON response and print it
    access_token = response.json()['access_token']
    print(f'OAuth access token: {access_token}')
else:
    # If the response is not successful, print an error message with the response status code and text
    print(f'Error: {response.status_code} - {response.text}')
# Out:
# OAuth access token: x32wqloacqbfklkq7xs27se3sm0bag

# %%
# This is getting authorization code to get USER access token


# Twitch API endpoint URLs
AUTH_URL = 'https://id.twitch.tv/oauth2/authorize'
TOKEN_URL = 'https://id.twitch.tv/oauth2/token'

# Twitch app credentials
CLIENT_ID = 'HIDDEN'
CLIENT_SECRET = 'HIDDEN'
REDIRECT_URI = 'http://localhost:3000'

# Twitch API scopes
SCOPES = ['analytics:read:games', 'channel_read', 'bits:read', 'analytics:read:extensions']

# Step 1: Get authorization code
auth_params = {
    'client_id': CLIENT_ID,
    'redirect_uri': REDIRECT_URI,
    'response_type': 'code',
    'scope': ' '.join(SCOPES)
}
auth_url = AUTH_URL + '?' + '&'.join([f'{k}={v}' for k, v in auth_params.items()])
auth_url

#0soigmkmybwifckpd0dllbqxxembxk
# Out:
# 'https://id.twitch.tv/oauth2/authorize?client_id=ej8o39fm82oihzvhhqpkula18xw9ix&redirect_uri=http://localhost:3000&response_type=code&scope=analytics:read:games'

# %%
# This is to get USER access token with specified scopes

# Step 2: Exchange authorization code for access token
token_params = {
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
    'redirect_uri': REDIRECT_URI,
    'grant_type': 'authorization_code',
    'code': '0soigmkmybwifckpd0dllbqxxembxk'
}
response = requests.post(TOKEN_URL, params=token_params)

if response.status_code == 200:
    access_token = response.json()['access_token']
    print(f'Access token: {access_token}')
else:
    print('Error getting access token')
    print(response.content)
# Out:
# Access token: akuvuu3bc0m41gmonl3su4e99ro8ks

# %%
# Get Overwatch 2 General Information


# Set the URL and headers for the request
url = 'https://api.twitch.tv/helix/games'
headers = {
    'Authorization': 'Bearer 55qk0nuptjxy1ws1ts02rdachqm9ag',
    'Client-Id': 'ej8o39fm82oihzvhhqpkula18xw9ix'
    }

# Set the query parameters
params = {
    'name': 'Overwatch 2'
}

# Send the GET request and store the response
response = requests.get(url, headers=headers, params=params)

# Print the response content (data)
print(response.json())
# Out:
# {'data': [{'id': '515025', 'name': 'Overwatch 2', 'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/515025-{width}x{height}.jpg', 'igdb_id': '125174'}]}

# %%
# Getting TOP played Games in Twitch

import requests

headers = {
    'Authorization': 'Bearer akuvuu3bc0m41gmonl3su4e99ro8ks',
    'Client-ID': 'ej8o39fm82oihzvhhqpkula18xw9ix'
}

response_top = requests.get('https://api.twitch.tv/helix/games/top', headers=headers)

json_top = response_top.json()

pretty_json = json.dumps(json_top, indent=4)

print(pretty_json)
# Out:
# {
#     "data": [
#         {
#             "id": "509658",
#             "name": "Just Chatting",
#             "box_art_url": "https://static-cdn.jtvnw.net/ttv-boxart/509658-{width}x{height}.jpg",
#             "igdb_id": ""
#         },
#         {
#             "id": "32982",
#             "name": "Grand Theft Auto V",
#             "box_art_url": "https://static-cdn.jtvnw.net/ttv-boxart/32982_IGDB-{width}x{height}.jpg",
#             "igdb_id": "1020"
#         },
#         {
#             "id": "1095275650",
#             "name": "Hogwarts Legacy",
#             "box_art_url": "https://static-cdn.jtvnw.net/ttv-boxart/1095275650_IGDB-{width}x{height}.jpg",
#             "igdb_id": "136625"
#         },
#         {
#             "id": "21779",
#             "name": "League of Legends",
#             "box_art_url": "https://static-cdn.jtvnw.net/ttv-boxart/21779-{width}x{height}.jpg",
#             "igdb_id": "115"
#         },
#         {
#             "id": "2009321156",
# ...

# %%
# TOP games dict

top_games = {
    "game_id": [],
    "name": [],
    "box_art_url": [],
    "igdb_id" : [],
    }    

for item in json_top["data"]:
    top_games["game_id"].append(item["id"])
    top_games["name"].append(item["name"])
    top_games["box_art_url"].append(item["box_art_url"])
    top_games["igdb_id"].append(item["igdb_id"])

top_games
# Out:
# {'game_id': ['509658',
#   '32982',
#   '1095275650',
#   '21779',
#   '2009321156',
#   '518203',
#   '516575',
#   '33214',
#   '1865070091',
#   '515025',
#   '263490',
#   '27471',
#   '491931',
#   '491487',
#   '32399',
#   '1745202732',
#   '488615',
#   '512710',
#   '29595',
#   '511224'],
#  'name': ['Just Chatting',
#   'Grand Theft Auto V',
#   'Hogwarts Legacy',
#   'League of Legends',
#   'Dark and Darker',
#   'Sports',
#   'VALORANT',
#   'Fortnite',
#   'Watch TV',
#   'Overwatch 2',
#   'Rust',
#   'Minecraft',
#   'Escape from Tarkov',
#   'Dead by Daylight',
#   'Counter-Strike: Global Offensive',
#   'FIFA 23',
#   'Street Fighter V',
#   'Call of Duty: Warzone',
#   'Dota 2',
#   'Apex Legends'],
#  'box_art_url': ['https://static-cdn.jtvnw.net/ttv-boxart/509658-{width}x{height}.jpg',
#   'https://static-cdn.jtvnw.net/ttv-boxart/32982_IGDB-{width}x{height}.jpg',
#   'https://static-cdn.jtvnw.net/ttv-boxart/1095275650_IGDB-{width}x{height}.jpg',
# ...

# %%
# TOP games df

df_top_games = pd.DataFrame(top_games)

# %%
df_top_games
# Out:
#        game_id                              name  \
# 0       509658                     Just Chatting
# 1        32982                Grand Theft Auto V
# 2   1095275650                   Hogwarts Legacy
# 3        21779                 League of Legends
# 4   2009321156                   Dark and Darker
# 5       518203                            Sports
# 6       516575                          VALORANT
# 7        33214                          Fortnite
# 8   1865070091                          Watch TV
# 9       515025                       Overwatch 2
# 10      263490                              Rust
# 11       27471                         Minecraft
# 12      491931                Escape from Tarkov
# 13      491487                  Dead by Daylight
# 14       32399  Counter-Strike: Global Offensive
# 15  1745202732                           FIFA 23
# 16      488615                  Street Fighter V
# 17      512710             Call of Duty: Warzone
# ...

# %%
# Getting Overwatch 2 Streams

import requests

url = 'https://api.twitch.tv/helix/streams'
headers = {
    'Authorization': 'Bearer akuvuu3bc0m41gmonl3su4e99ro8ks',
    'Client-Id': 'ej8o39fm82oihzvhhqpkula18xw9ix'
}

# Set the query parameters
params = {
    'game_id': '515025',
    'first': 100,

}

response_owstreams = requests.get(url, headers=headers, params=params)

json_owstreams = response_owstreams.json()

pretty_json = json.dumps(json_owstreams, indent=4)

print(pretty_json)
# Out:
# {
#     "data": [
#         {
#             "id": "41843937451",
#             "user_id": "147927227",
#             "user_login": "aspen",
#             "user_name": "Aspen",
#             "game_id": "515025",
#             "game_name": "Overwatch 2",
#             "type": "live",
#             "title": "[DROPS] GM1 games. support grinDDDD",
#             "viewer_count": 5326,
#             "started_at": "2023-02-12T22:55:32Z",
#             "language": "en",
#             "thumbnail_url": "https://static-cdn.jtvnw.net/previews-ttv/live_user_aspen-{width}x{height}.jpg",
#             "tag_ids": [
#                 "c2542d6d-cd10-4532-919b-3d19f30a768b",
#                 "6ea6bca4-4712-4ab9-a906-e3336a9d8039"
#             ],
#             "tags": [
#                 "English",
#                 "DropsEnabled"
#             ],
#             "is_mature": false
#         },
#         {
#             "id": "40917478585",
#             "user_id": "53648099",
# ...

# %%
# Getting Overwatch 2 Streams PAGE 2

import requests

url = 'https://api.twitch.tv/helix/streams'
headers = {
    'Authorization': 'Bearer akuvuu3bc0m41gmonl3su4e99ro8ks',
    'Client-Id': 'ej8o39fm82oihzvhhqpkula18xw9ix'
}

# Set the query parameters
params = {
    'game_id': '515025',
    'first': 100,
    'after': 'eyJiIjp7IkN1cnNvciI6ImV5SnpJam8xTXpJMkxqWTJNalk0T1RJek1UUTVNU3dpWkNJNlptRnNjMlVzSW5RaU9uUnlkV1Y5In0sImEiOnsiQ3Vyc29yIjoiZXlKeklqb3lPQzR4TlRVeE1qRXhPRFUyT0RNd09UTXNJbVFpT21aaGJITmxMQ0owSWpwMGNuVmxmUT09In19'

}

response_owstreams = requests.get(url, headers=headers, params=params)

json_owstreams2 = response_owstreams.json()

pretty_json = json.dumps(json_owstreams2, indent=4)

print(pretty_json)
# Out:
# {
#     "data": [
#         {
#             "id": "47961419453",
#             "user_id": "710323385",
#             "user_login": "mastergwinn",
#             "user_name": "MasterGwinn",
#             "game_id": "515025",
#             "game_name": "Overwatch 2",
#             "type": "live",
#             "title": "\u3010Vtuber\u3011 (ENG/ESP) | Sondei fondei | It's so colddddddd, i requiere group hug | We kill a couple bosses and the overgwatch games meibi",
#             "viewer_count": 26,
#             "started_at": "2023-02-13T00:28:11Z",
#             "language": "en",
#             "thumbnail_url": "https://static-cdn.jtvnw.net/previews-ttv/live_user_mastergwinn-{width}x{height}.jpg",
#             "tag_ids": [
#                 "6ea6bca4-4712-4ab9-a906-e3336a9d8039"
#             ],
#             "tags": [
#                 "Vtuber",
#                 "Anime",
#                 "Latino",
#                 "Gamer",
#                 "OneBrainCell",
#                 "Cute",
# ...

# %%
# Getting Overwatch 2 Streams PAGE 3

import requests

url = 'https://api.twitch.tv/helix/streams'
headers = {
    'Authorization': 'Bearer akuvuu3bc0m41gmonl3su4e99ro8ks',
    'Client-Id': 'ej8o39fm82oihzvhhqpkula18xw9ix'
}

# Set the query parameters
params = {
    'game_id': '515025',
    'first': 100,
    'after': 'eyJiIjp7IkN1cnNvciI6ImV5SnpJam95Tmk0NU9ERTVNVFF3T0RJMU16YzROVElzSW1RaU9tWmhiSE5sTENKMElqcDBjblZsZlE9PSJ9LCJhIjp7IkN1cnNvciI6ImV5SnpJam94TXk0eE9EQTFOekkyTWpBeU16SXpOelFzSW1RaU9tWmhiSE5sTENKMElqcDBjblZsZlE9PSJ9fQ'

}

response_owstreams = requests.get(url, headers=headers, params=params)

json_owstreams3 = response_owstreams.json()

pretty_json = json.dumps(json_owstreams3, indent=4)

print(pretty_json)
# Out:
# {
#     "data": [
#         {
#             "id": "40072647031",
#             "user_id": "670945673",
#             "user_login": "tenyo1",
#             "user_name": "tenyo1",
#             "game_id": "515025",
#             "game_name": "Overwatch 2",
#             "type": "live",
#             "title": "\u4eca\u65e5\u3082\u305f\u306e\u3057\u304f\u304a\u30fc\u3070\u30fc\u304a drops",
#             "viewer_count": 20,
#             "started_at": "2023-02-13T03:33:58Z",
#             "language": "ja",
#             "thumbnail_url": "https://static-cdn.jtvnw.net/previews-ttv/live_user_tenyo1-{width}x{height}.jpg",
#             "tag_ids": [
#                 "c2542d6d-cd10-4532-919b-3d19f30a768b",
#                 "6ba1d230-e52f-4d81-b1e0-41f25a8a9f5d"
#             ],
#             "tags": [
#                 "\u65e5\u672c\u8a9e",
#                 "Drops\u6709\u52b9"
#             ],
#             "is_mature": false
#         },
#         {
#             "id": "40072301671",
# ...

# %%
from datetime import datetime

# Streams Dict

ow_streams = {
    "streamid": [],
    "user_id": [],
    "user_name": [],
    "game_id" : [],
    "game_name" : [],
    "type": [],
    "title": [],
    "viewer_count": [],
    "started_at" : [],
    "language" : [],
    "thumbnail_url" : [],
    }    

for item in json_owstreams["data"]:
    ow_streams["streamid"].append(item["id"])
    ow_streams["user_id"].append(item["user_id"])
    ow_streams["user_name"].append(item["user_name"])
    ow_streams["game_id"].append(item["game_id"])
    ow_streams["game_name"].append(item["game_name"])
    ow_streams["type"].append(item["type"])
    ow_streams["title"].append(item["title"])
    ow_streams["viewer_count"].append(item["viewer_count"])

    original_str = item["started_at"]
    dt = datetime.strptime(original_str, "%Y-%m-%dT%H:%M:%SZ")
    new_str = dt.strftime("%m-%d-%Y %H:%M:%S")
    ow_streams["started_at"].append(new_str)

    ow_streams["language"].append(item["language"])
    ow_streams["thumbnail_url"].append(item["thumbnail_url"])
    
for item in json_owstreams2["data"]:
    ow_streams["streamid"].append(item["id"])
    ow_streams["user_id"].append(item["user_id"])
    ow_streams["user_name"].append(item["user_name"])
    ow_streams["game_id"].append(item["game_id"])
    ow_streams["game_name"].append(item["game_name"])
    ow_streams["type"].append(item["type"])
    ow_streams["title"].append(item["title"])
    ow_streams["viewer_count"].append(item["viewer_count"])

    original_str = item["started_at"]
    dt = datetime.strptime(original_str, "%Y-%m-%dT%H:%M:%SZ")
    new_str = dt.strftime("%m-%d-%Y %H:%M:%S")
    ow_streams["started_at"].append(new_str)

    ow_streams["language"].append(item["language"])
    ow_streams["thumbnail_url"].append(item["thumbnail_url"])

for item in json_owstreams3["data"]:
    ow_streams["streamid"].append(item["id"])
    ow_streams["user_id"].append(item["user_id"])
    ow_streams["user_name"].append(item["user_name"])
    ow_streams["game_id"].append(item["game_id"])
    ow_streams["game_name"].append(item["game_name"])
    ow_streams["type"].append(item["type"])
    ow_streams["title"].append(item["title"])
    ow_streams["viewer_count"].append(item["viewer_count"])

    original_str = item["started_at"]
    dt = datetime.strptime(original_str, "%Y-%m-%dT%H:%M:%SZ")
    new_str = dt.strftime("%m-%d-%Y %H:%M:%S")
    ow_streams["started_at"].append(new_str)

    ow_streams["language"].append(item["language"])
    ow_streams["thumbnail_url"].append(item["thumbnail_url"])

# %%
# Streams dict to df

df_streams = pd.DataFrame(ow_streams)

# %%
df_streams
# Out:
#         streamid    user_id        user_name game_id    game_name  type  \
# 0    41843937451  147927227            Aspen  515025  Overwatch 2  live
# 1    40917478585   53648099             Warn  515025  Overwatch 2  live
# 2    41844429627  131986952        FroggerOW  515025  Overwatch 2  live
# 3    41843353515   80272696     RubenSargasm  515025  Overwatch 2  live
# 4    40916716617  145686333            eskay  515025  Overwatch 2  live
# ..           ...        ...              ...     ...          ...   ...
# 293  47961439325  160057326   urbrokenfriend  515025  Overwatch 2  live
# 294  47961988797  161558580  pewpiepiepewper  515025  Overwatch 2  live
# 295  47961886349   66206805     TurtleCatz01  515025  Overwatch 2  live
# 296  40919534025  825578343   DaddyShaneDoes  515025  Overwatch 2  live
# 297  40918488521  568590341         JokstrTV  515025  Overwatch 2  live
#
#                                                  title  viewer_count  \
# ...

# %%
# Scraping Overwatch2 tags information

ow_tags = {
    "stream_id": [],
    'tags': []}

for item in json_owstreams["data"]:
    ow_tags["stream_id"].append(item["id"])
    ow_tags["tags"].append(item["tags"])

for item in json_owstreams2["data"]:
    ow_tags["stream_id"].append(item["id"])
    ow_tags["tags"].append(item["tags"])

for item in json_owstreams3["data"]:
    ow_tags["stream_id"].append(item["id"])
    ow_tags["tags"].append(item["tags"])

ow_tags
# Out:
# {'stream_id': ['41843937451',
#   '40917478585',
#   '41844429627',
#   '41843353515',
#   '40916716617',
#   '40072370583',
#   '47960353341',
#   '41843870091',
#   '40469349256',
#   '40917530681',
#   '40911171001',
#   '40072581335',
#   '47960395597',
#   '41843819131',
#   '39334288677',
#   '40914338585',
#   '40069240807',
#   '40072362951',
#   '40915717065',
#   '41844436059',
#   '40919116169',
#   '41843605515',
#   '41843443083',
#   '47961207661',
#   '47961909165',
#   '41844052331',
#   '40072296983',
#   '41844213611',
#   '46609686636',
#   '47962263773',
#   '40917419801',
#   '40918789929',
#   '40918082265',
#   '40918114777',
#   '40468454472',
#   '47961721037',
#   '40072335687',
#   '41844173419',
#   '40072436807',
#   '40071302823',
#   '40072366391',
#   '40917877961',
#   '41844135451',
#   '40918128073',
#   '40072021367',
#   '47960156269',
#   '39334202741',
#   '47961283565',
#   '41844178651',
#   '41844430027',
#   '40919016425',
# ...

# %%
# tags to df

df_tags = pd.DataFrame(ow_tags)

# %%
df_tags
# Out:
#        stream_id         tags
# 0    41843937451      English
# 1    40917478585    Overwatch
# 2    41844429627   Australian
# 3    41843353515     Armenian
# 4    40916716617    Overwatch
# ..           ...          ...
# 293  47961439325      English
# 294  47961988797      Asexual
# 295  47961886349     chilling
# 296  40919534025      English
# 297  40918488521  LGBTQIAPlus
#
# [298 rows x 2 columns]

# %%
# Getting Overwatch 2 Videos 

import requests

url = 'https://api.twitch.tv/helix/videos'
headers = {
    'Authorization': 'Bearer akuvuu3bc0m41gmonl3su4e99ro8ks',
    'Client-Id': 'ej8o39fm82oihzvhhqpkula18xw9ix'
}

# Set the query parameters
params = {
    'game_id': '515025',
    'sort' : 'views',
    'first' : 100,
}

response_owgames = requests.get(url, headers=headers, params=params)

json_owgames1 = response_owgames.json()

pretty_json = json.dumps(json_owgames1, indent=4)

print(pretty_json)
# Out:
# {
#     "data": [
#         {
#             "id": "1680478024",
#             "stream_id": "39927364007",
#             "user_id": "156037856",
#             "user_login": "fextralife",
#             "user_name": "Fextralife",
#             "title": "[DROPS ON] STILL CANT GET TO DIAMOND SADGE",
#             "description": "",
#             "created_at": "2022-12-16T11:03:23Z",
#             "published_at": "2022-12-16T11:03:23Z",
#             "url": "https://www.twitch.tv/videos/1680478024",
#             "thumbnail_url": "https://static-cdn.jtvnw.net/cf_vods/d3vd9lfkzbru3h/1f94fd1fc9a79b24d361_fextralife_39927364007_1671188596//thumb/thumb0-%{width}x%{height}.jpg",
#             "viewable": "public",
#             "view_count": 1076098,
#             "language": "en",
#             "type": "archive",
#             "duration": "10h19m40s",
#             "muted_segments": null
#         },
#         {
#             "id": "1623320524",
#             "stream_id": "41386122331",
# ...

# %%
# Getting Overwatch 2 Videos SECOND PAGE

import requests

url = 'https://api.twitch.tv/helix/videos'
headers = {
    'Authorization': 'Bearer akuvuu3bc0m41gmonl3su4e99ro8ks',
    'Client-Id': 'ej8o39fm82oihzvhhqpkula18xw9ix'
}

# Set the query parameters
params = {
    'game_id': '515025',
    'sort' : 'views',
    'first' : 100,
    'after': 'eyJiIjpudWxsLCJhIjp7Ik9mZnNldCI6MTAwfX0'
}

response_owgames = requests.get(url, headers=headers, params=params)

json_owgames2 = response_owgames.json()

pretty_json = json.dumps(json_owgames2, indent=4)

print(pretty_json)
# Out:
# {
#     "data": [
#         {
#             "id": "1691702939",
#             "stream_id": "39958079159",
#             "user_id": "74255608",
#             "user_login": "overwatchkr",
#             "user_name": "\uc624\ubc84\uc6cc\uce58",
#             "title": "\uc624\ubc84\uc6cc\uce58 2 \ub300\ud559 \ud1a0\ub108\uba3c\ud2b8 4\uac15 1\uacbd\uae30 \uc11c\uac15\ub300\ud559\uad50 vs \uc2e0\uad6c\ub300\ud559\uad50",
#             "description": "",
#             "created_at": "2022-12-29T04:36:01Z",
#             "published_at": "2022-12-29T04:36:01Z",
#             "url": "https://www.twitch.tv/videos/1691702939",
#             "thumbnail_url": "https://static-cdn.jtvnw.net/cf_vods/d3vd9lfkzbru3h/23356e2c7db73a5c87bc_overwatchkr_39958079159_1672288555//thumb/thumb0-%{width}x%{height}.jpg",
#             "viewable": "public",
#             "view_count": 169857,
#             "language": "ko",
#             "type": "archive",
#             "duration": "6h8m59s",
# ...

# %%
# Getting Overwatch 2 Videos THIRD PAGE

import requests

url = 'https://api.twitch.tv/helix/videos'
headers = {
    'Authorization': 'Bearer akuvuu3bc0m41gmonl3su4e99ro8ks',
    'Client-Id': 'ej8o39fm82oihzvhhqpkula18xw9ix'
}

# Set the query parameters
params = {
    'game_id': '515025',
    'sort' : 'views',
    'first' : 100,
    'after': 'eyJiIjp7Ik9mZnNldCI6MH0sImEiOnsiT2Zmc2V0IjoyMDB9fQ'
}

response_owgames = requests.get(url, headers=headers, params=params)

json_owgames3 = response_owgames.json()

pretty_json = json.dumps(json_owgames3, indent=4)

print(pretty_json)
# Out:
# {
#     "data": [
#         {
#             "id": "1717108375",
#             "stream_id": "47852623421",
#             "user_id": "141429177",
#             "user_login": "flats",
#             "user_name": "Flats",
#             "title": "[DROPS ENABLED] PATCH TODAY 1PM EST + DISCUSSION WITH LEAD HERO DESIGNER ALEC DAWSON",
#             "description": "",
#             "created_at": "2023-01-24T16:34:20Z",
#             "published_at": "2023-01-24T16:34:20Z",
#             "url": "https://www.twitch.tv/videos/1717108375",
#             "thumbnail_url": "https://static-cdn.jtvnw.net/cf_vods/d1m7jfoe9zdc1j/e1f6349a4688c6d2e05b_flats_47852623421_1674578055//thumb/thumb0-%{width}x%{height}.jpg",
#             "viewable": "public",
#             "view_count": 107259,
#             "language": "en",
#             "type": "archive",
#             "duration": "6h52m26s",
#             "muted_segments": null
#         },
#         {
#             "id": "1726804941",
# ...

# %%
#videos dict


from datetime import timedelta
from datetime import datetime


ow_videos = {
    "video_id": [],
    "stream_id": [],
    "user_id": [],
    "user_login" : [],
    "user_name" : [],
    "title" : [],
    "created_at": [],
    "published_at": [],
    "url": [],
    "thumbnail_url" : [],
    "viewable" : [],
    "view_count" : [],
    "language" : [],
    "type" : [],
    "duration" : [],
    "muted_segments" : [],
    }  

for video in json_owgames1["data"]:
    ow_videos["video_id"].append(video["id"])
    ow_videos["stream_id"].append(video["stream_id"])
    ow_videos["user_id"].append(video["user_id"])
    ow_videos["user_login"].append(video["user_login"])
    ow_videos["user_name"].append(video["user_name"])
    ow_videos["title"].append(video["title"])

    original_str = video["created_at"]
    dt = datetime.strptime(original_str, "%Y-%m-%dT%H:%M:%SZ")
    new_str = dt.strftime("%Y-%m-%d %H:%M:%S")
    ow_videos["created_at"].append(new_str)


    ogstr = video["published_at"]
    dte = datetime.strptime(ogstr, "%Y-%m-%dT%H:%M:%SZ")
    nstr = dte.strftime("%Y-%m-%d %H:%M:%S")
    ow_videos["published_at"].append(nstr)

    ow_videos["url"].append(video["url"])
    ow_videos["thumbnail_url"].append(video["thumbnail_url"])
    ow_videos["viewable"].append(video["viewable"])
    ow_videos["view_count"].append(video["view_count"])
    ow_videos["language"].append(video["language"])
    ow_videos["type"].append(video["type"])

    duration_str = video["duration"]

    if "h" in duration_str:
        hours = int(duration_str.split("h")[0])
        minutes = int(duration_str.split("h")[1].split("m")[0])
        seconds = int(duration_str.split("m")[1].split("s")[0])
    else:
        hours = 0
        minutes = int(duration_str.split("m")[0])
        seconds = int(duration_str.split("m")[1].split("s")[0])

    duration_time = timedelta(hours=hours, minutes=minutes, seconds=seconds)
    duration_formatted = str(duration_time)

    ow_videos["duration"].append(duration_formatted)

    ow_videos["muted_segments"].append(video["muted_segments"])

for video in json_owgames2["data"]:
    ow_videos["video_id"].append(video["id"])
    ow_videos["stream_id"].append(video["stream_id"])
    ow_videos["user_id"].append(video["user_id"])
    ow_videos["user_login"].append(video["user_login"])
    ow_videos["user_name"].append(video["user_name"])
    ow_videos["title"].append(video["title"])

    original_str = video["created_at"]
    dt = datetime.strptime(original_str, "%Y-%m-%dT%H:%M:%SZ")
    new_str = dt.strftime("%Y-%m-%d %H:%M:%S")
    ow_videos["created_at"].append(new_str)



    ogstr = video["published_at"]
    dte = datetime.strptime(ogstr, "%Y-%m-%dT%H:%M:%SZ")
    nstr = dte.strftime("%Y-%m-%d %H:%M:%S")
    ow_videos["published_at"].append(nstr)

    ow_videos["url"].append(video["url"])
    ow_videos["thumbnail_url"].append(video["thumbnail_url"])
    ow_videos["viewable"].append(video["viewable"])
    ow_videos["view_count"].append(video["view_count"])
    ow_videos["language"].append(video["language"])
    ow_videos["type"].append(video["type"])

    if "h" in duration_str:
        hours = int(duration_str.split("h")[0])
        minutes = int(duration_str.split("h")[1].split("m")[0])
        seconds = int(duration_str.split("m")[1].split("s")[0])
    else:
        hours = 0
        minutes = int(duration_str.split("m")[0])
        seconds = int(duration_str.split("m")[1].split("s")[0])

    duration_time = timedelta(hours=hours, minutes=minutes, seconds=seconds)
    duration_formatted = str(duration_time)

    ow_videos["duration"].append(duration_formatted)


    ow_videos["muted_segments"].append(video["muted_segments"])

for video in json_owgames3["data"]:
    ow_videos["video_id"].append(video["id"])
    ow_videos["stream_id"].append(video["stream_id"])
    ow_videos["user_id"].append(video["user_id"])
    ow_videos["user_login"].append(video["user_login"])
    ow_videos["user_name"].append(video["user_name"])
    ow_videos["title"].append(video["title"])


    original_str = video["created_at"]
    dt = datetime.strptime(original_str, "%Y-%m-%dT%H:%M:%SZ")
    new_str = dt.strftime("%Y-%m-%d %H:%M:%S")
    ow_videos["created_at"].append(new_str)



    ogstr = video["published_at"]
    dte = datetime.strptime(ogstr, "%Y-%m-%dT%H:%M:%SZ")
    nstr = dte.strftime("%Y-%m-%d %H:%M:%S")
    ow_videos["published_at"].append(nstr)
    
    ow_videos["url"].append(video["url"])
    ow_videos["thumbnail_url"].append(video["thumbnail_url"])
    ow_videos["viewable"].append(video["viewable"])
    ow_videos["view_count"].append(video["view_count"])
    ow_videos["language"].append(video["language"])
    ow_videos["type"].append(video["type"])

    if "h" in duration_str:
        hours = int(duration_str.split("h")[0])
        minutes = int(duration_str.split("h")[1].split("m")[0])
        seconds = int(duration_str.split("m")[1].split("s")[0])
    else:
        hours = 0
        minutes = int(duration_str.split("m")[0])
        seconds = int(duration_str.split("m")[1].split("s")[0])

    duration_time = timedelta(hours=hours, minutes=minutes, seconds=seconds)
    duration_formatted = str(duration_time)

    ow_videos["duration"].append(duration_formatted)


    ow_videos["muted_segments"].append(video["muted_segments"])

# %%
# videos to df
df_videos = pd.DataFrame(ow_videos)

# %%
df_videos
# Out:
#        video_id    stream_id    user_id  user_login   user_name  \
# 0    1680478024  39927364007  156037856  fextralife  Fextralife
# 1    1623320524  41386122331   37402112      shroud      shroud
# 2    1632407043  41416747371   37402112      shroud      shroud
# 3    1618762479  41366845515   37402112      shroud      shroud
# 4    1708974798  40000757447  156037856  fextralife  Fextralife
# ..          ...          ...        ...         ...         ...
# 295  1680420303  40183520936   41314239      dafran      dafran
# 296  1705352368  41714460843   19070311   a_seagull   A_Seagull
# 297  1683195393  47649287261   23220337      emongg      Emongg
# 298  1735306072  40911156393    4329841     harbleu     harbleu
# 299  1696720423  41679373851   19070311   a_seagull   A_Seagull
#
#                                                  title           created_at  \
# 0           [DROPS ON] STILL CANT GET TO DIAMOND SADGE  2022-12-16 11:03:23
# ...

# %%
# appending to sql table videos_twitch
df_videos.to_sql(name='videos_twitch', con=engine, if_exists='append', index=False)
# Out:
# 300

# %%
# appending to sql table streams_twitch
df_streams.to_sql(name='streams_twitch', con=engine, if_exists='append', index=False)
# Out:
# 298

# %%
# appending to sql table top_games_twitch
df_top_games.to_sql(name='top_games_twitch', con=engine, if_exists='append', index=False)
# Out:
# 20

# %%
# appending to sql table tags_streams_twitch
df_tags.to_sql(name='tags_streams_twitch', con=engine, if_exists='append', index=False)
# Out:
# 298
